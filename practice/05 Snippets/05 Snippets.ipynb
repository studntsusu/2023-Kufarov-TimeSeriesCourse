# %% [markdown]
# # Анализ и прогнозирование временных рядов методами искусственного интеллекта
#
# ## **Практическая работа 5. Поиск типичных подпоследовательностей временного ряда.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/2023-Kufarov-TimeSeriesCourse-main/practice/05 Snippets')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install matrixprofile
# Out:
# Collecting matrixprofile
#   Downloading matrixprofile-1.1.10.tar.gz (331 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.6/331.6 kB 5.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install -U kaleido
# Out:
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.1 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
# !pip install stumpy
# Out:
# Collecting stumpy
#   Downloading stumpy-1.12.0-py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from stumpy) (1.25.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from stumpy) (1.11.4)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.10/dist-packages (from stumpy) (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.2->stumpy) (0.41.1)
# Installing collected packages: stumpy
# Successfully installed stumpy-1.12.0

# %% [markdown]
# Импорт библиотек и модулей

# %%
import numpy as np
import matplotlib.pyplot as plt
from modules.snippets import *
from scipy import signal
from modules.snippets import plot_snippets
import pandas as pd
from sklearn.metrics import accuracy_score
import plotly.express as px
from stumpy import snippets

# %% [markdown]
# ### **Задача 1. Поиск сниппетов одномерного временного ряда**
#
# В первой задаче необходимо выполнить поиск сниппетов одномерного временного ряда. Расмотрите приведенный ниже пример использования алгоритма SnipperFinder и визуализации полученных результатов для искуственного врменного ряда.

# %%
#Создание искусственного временного ряда
t = np.linspace(np.pi, 6 * 2 * np.pi, 3000)
ts = np.concatenate([np.sin(t), signal.sawtooth(t)])
plt.plot(ts)

# %%
#Поиск сниппетов
snp = snippets(ts, 600, 2)

# %%
#Визуализация результатов
plot_snippets(ts, snp)
# Out:
# 600
# <Axes: >

# %% [markdown]
# Далее вам предстоит самостоятельно выполнить поиск top-$k$ типичных подпоследовательностей временного ряда (сниппетов) с помощью алгоритма SnippetFinder на наборе данных PAMAP. Описание набора данных находится в [README-файле](datasets/PAMAP/readme.md).
#
# Выполните считывание временного ряда **показаний гироскопа на оси «X» (угол крена) на временном интервале от 950 сек. до 109 сек.** из файла *PAMAP.txt*, который располагается в директории *./datasets/PAMAP*. Затем выполните поиск сниппетов с помощью функции `snippets()` из модуля snippets.py.

# %% [markdown]
# **Сниппет (snippet)** представляет собой подпоследовательность заданной длины, на которую похожи многие другие подпоследовательности данного ряда в смысле специально определяемой меры схожести. Набор сниппетов имеет существенно меньшую мощность, чем множество подпоследовательностей ряд.
#
# **Каждый сниппет** представляет собой
# один из сегментов временн´ого ряда. Со сниппетом ассоциируются его ближайшие
# соседи — подпоследовательности ряда, имеющие ту же длину, что и сниппет, которые более похожи на данный сниппет,
# чем на другие сегменты. Для вычисления схожести подпоследовательностей используется специализированная мера схожести, основанная на евклидовом расстоянии. Сниппеты упорядочиваются по убыванию
# мощности множества своих ближайших соседей.

# %%
import pandas as pd

ts_url = './datasets/PAMAP/PAMAP.txt'

df = pd.read_csv(ts_url, sep=' ', header=None).T
start_time = 1790
end_time = 1930

ts = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 11].to_numpy()

# %%
snp = snippets(ts, 2000, 2, s=1000)

# %%
df
# Out:
#              0    1     2        3         4        5         6         7   \
# 0        505.71  2.0   NaN  35.0625  0.497271  9.08249 -1.875540  0.319610
# 1        505.72  2.0   NaN  35.0625  0.693164  8.93258 -1.677900  0.379878
# 2        505.73  2.0  79.0  35.0625  0.929013  9.04638 -1.441670  0.606483
# 3        505.74  2.0   NaN  35.0625  1.039680  9.38386 -1.595650  0.772609
# 4        505.75  2.0   NaN  35.0625  1.070930  9.38219 -1.827400  0.938327
# ...         ...  ...   ...      ...       ...      ...       ...       ...
# 145995  2305.66  4.0   NaN  35.6875  2.140840  7.09274 -0.213018  2.107840
# 145996  2305.67  4.0   NaN  35.6875  2.027390  6.56647 -0.135921  2.015190
# 145997  2305.68  4.0   NaN  35.6875  1.978930  6.11268 -0.445092  1.861420
# 145998  2305.69  4.0   NaN  35.6875  1.677590  5.73813 -0.294450  1.707950
# 145999  2305.70  4.0   NaN  35.6875  1.217980  5.32511 -0.340155  1.449760
#
#              8         9         10        11        12        13       14  \
# 0       9.10631 -1.642520 -0.064955  0.033557  0.051343   2.52139 -23.9094
# 1       8.90965 -1.416770  0.063998  0.052043  0.078401   2.12795 -23.8953
# 2       8.89380 -1.236830  0.192540  0.034474  0.070010   1.87388 -24.2730
# 3       8.99907 -1.237530  0.282665  0.053817  0.057465   1.73597 -23.3649
# 4       9.21025 -1.419260  0.335187  0.016476  0.011713   2.25530 -24.4165
# ...         ...       ...       ...       ...       ...       ...      ...
# 145995  7.31908 -0.041456  0.256645 -0.568124  0.005918 -12.27830 -50.9797
# 145996  6.94196 -0.041992  0.221546 -0.501649  0.103945 -12.52640 -51.7445
# 145997  6.39894 -0.027528  0.162119 -0.355711  0.133332 -11.76720 -51.6443
# 145998  5.96165 -0.073210  0.122680 -0.262807  0.188172 -12.41520 -51.3625
# 145999  5.60004 -0.102927  0.060416 -0.171433  0.201760 -12.02680 -51.5058
#
#               15        16        17        18        19
# 0        3.66977  0.636708 -0.766698  0.073248  0.037565
# 1        4.08997  0.636387 -0.766974  0.073379  0.037113
# 2        4.23135  0.635648 -0.767586  0.073587  0.036706
# 3        3.94322  0.635121 -0.768060  0.073553  0.035983
# 4        4.65783  0.633378 -0.769606  0.072906  0.034988
# ...          ...       ...       ...       ...       ...
# 145995  20.50000  0.566790 -0.673692 -0.347012 -0.323220
# 145996  20.64360  0.566736 -0.675315 -0.345593 -0.321443
# 145997  21.35340  0.566580 -0.676581 -0.344391 -0.320344
# 145998  21.34730  0.566308 -0.677672 -0.343209 -0.319786
# 145999  21.35080  0.566066 -0.678469 -0.342133 -0.319678
#
# [146000 rows x 20 columns]

# %% [markdown]
# Выполните визулизацию временного ряда и найденных сниппетов с помощью функции `plot_snippets()` из модуля snippets.py.

# %%
plot_snippets(ts, snp)
# Out:
# 2000
# <Axes: >

# %% [markdown]
# Оцените точность разметки, полученной при помощи сниппетов.

# %%
labels_pred = np.zeros_like(ts)
snippets_regimes = snp[-1]
for regime in snippets_regimes:
  labels_pred[regime[1] : regime[2]] = regime[0]

# %%
# получаем правильные метки
labels = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 1].to_numpy()
labels = np.where(labels == 12, 0, labels)
labels = np.where(labels == 13, 1, labels)

accuracy_score(labels, labels_pred)
# Out:
# 0.8026658723657756

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов.

# %% [markdown]
# С помощью сниппетов можно кластеризовывать временные ряды

# %% [markdown]
# ### Задача 2. Разметка многомерного временного ряда
#
# Выполните разметку многомерного временно ряда, используя **показания гироскопа по всем трем осям** из набора данных PAMAP. Используйте тот же временной интервал, что и в задаче 1.

# %%
df
# Out:
#              0    1     2        3         4        5         6         7   \
# 0        505.71  2.0   NaN  35.0625  0.497271  9.08249 -1.875540  0.319610
# 1        505.72  2.0   NaN  35.0625  0.693164  8.93258 -1.677900  0.379878
# 2        505.73  2.0  79.0  35.0625  0.929013  9.04638 -1.441670  0.606483
# 3        505.74  2.0   NaN  35.0625  1.039680  9.38386 -1.595650  0.772609
# 4        505.75  2.0   NaN  35.0625  1.070930  9.38219 -1.827400  0.938327
# ...         ...  ...   ...      ...       ...      ...       ...       ...
# 145995  2305.66  4.0   NaN  35.6875  2.140840  7.09274 -0.213018  2.107840
# 145996  2305.67  4.0   NaN  35.6875  2.027390  6.56647 -0.135921  2.015190
# 145997  2305.68  4.0   NaN  35.6875  1.978930  6.11268 -0.445092  1.861420
# 145998  2305.69  4.0   NaN  35.6875  1.677590  5.73813 -0.294450  1.707950
# 145999  2305.70  4.0   NaN  35.6875  1.217980  5.32511 -0.340155  1.449760
#
#              8         9         10        11        12        13       14  \
# 0       9.10631 -1.642520 -0.064955  0.033557  0.051343   2.52139 -23.9094
# 1       8.90965 -1.416770  0.063998  0.052043  0.078401   2.12795 -23.8953
# 2       8.89380 -1.236830  0.192540  0.034474  0.070010   1.87388 -24.2730
# 3       8.99907 -1.237530  0.282665  0.053817  0.057465   1.73597 -23.3649
# 4       9.21025 -1.419260  0.335187  0.016476  0.011713   2.25530 -24.4165
# ...         ...       ...       ...       ...       ...       ...      ...
# 145995  7.31908 -0.041456  0.256645 -0.568124  0.005918 -12.27830 -50.9797
# 145996  6.94196 -0.041992  0.221546 -0.501649  0.103945 -12.52640 -51.7445
# 145997  6.39894 -0.027528  0.162119 -0.355711  0.133332 -11.76720 -51.6443
# 145998  5.96165 -0.073210  0.122680 -0.262807  0.188172 -12.41520 -51.3625
# 145999  5.60004 -0.102927  0.060416 -0.171433  0.201760 -12.02680 -51.5058
#
#               15        16        17        18        19
# 0        3.66977  0.636708 -0.766698  0.073248  0.037565
# 1        4.08997  0.636387 -0.766974  0.073379  0.037113
# 2        4.23135  0.635648 -0.767586  0.073587  0.036706
# 3        3.94322  0.635121 -0.768060  0.073553  0.035983
# 4        4.65783  0.633378 -0.769606  0.072906  0.034988
# ...          ...       ...       ...       ...       ...
# 145995  20.50000  0.566790 -0.673692 -0.347012 -0.323220
# 145996  20.64360  0.566736 -0.675315 -0.345593 -0.321443
# 145997  21.35340  0.566580 -0.676581 -0.344391 -0.320344
# 145998  21.34730  0.566308 -0.677672 -0.343209 -0.319786
# 145999  21.35080  0.566066 -0.678469 -0.342133 -0.319678
#
# [146000 rows x 20 columns]

# %%
#start_time = 840
#end_time = 870
start_time = 1790
end_time = 1930
ts1 = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 10].to_numpy()#x
ts2 = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 11].to_numpy()#y
ts3 = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 12].to_numpy()#z

# %%
plt.plot(ts1)

# %%
plt.plot(ts2)

# %%
plt.plot(ts3)

# %%
start_time = 850
end_time = 880

ts = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 10:13].to_numpy()
ts.shape
# Out:
# (2999, 3)

# %%
snp1 = snippets(ts1, 2000, 2, s=1000)
snp2 = snippets(ts2, 2000, 2, s=1000)
snp3 = snippets(ts3, 2000, 2, s=1000)

# %%
plt.plot(ts1)
plt.plot(ts2)
plt.plot(ts3)

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# Предполагается, что snp1, snp2, snp3 - это сниппеты для каждой оси
snp1 = snippets(ts1, 2000, 2, s=1000)
snp2 = snippets(ts2, 2000, 2, s=1000)
snp3 = snippets(ts3, 2000, 2, s=1000)

# Создаем массив для хранения предсказанных меток
labels_pred = np.zeros_like(ts)

# Перебираем сниппеты для каждой оси гироскопа
for snp in [snp1, snp2, snp3]:
    snippets_regimes = snp[-1]

    # Присваиваем предсказанные метки в соответствии с режимами сниппетов
    for regime in snippets_regimes:
        labels_pred[regime[1]:regime[2], :] = regime[0]

# сравнению с фактическими метками
start_time = 850
end_time = 880
labels = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 1].to_numpy()
labels = np.where(labels == 12, 0, labels)
labels = np.where(labels == 13, 1, labels)

# %%
from sklearn.metrics import accuracy_score

# сравнению с фактическими метками для каждой оси
start_time = 850
end_time = 880
labels_axis1 = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 1].to_numpy()
labels_axis1 = np.where(labels_axis1 == 12, 0, labels_axis1)
labels_axis1 = np.where(labels_axis1 == 13, 1, labels_axis1)


# Точность для оси 1,2,3
accuracy_axis1 = accuracy_score(labels_axis1, labels_pred[:, 0])


# Вывод результатов для каждой оси
print(f'Accuracy Axis 1: {accuracy_axis1}')
# Out:
# Accuracy Axis 1: 0.0

# %%
snp = []
snp.append(snippets(ts[:,0], 500, 2))
snp.append(snippets(ts[:,1], 500, 2))
snp.append(snippets(ts[:,2], 500, 2))

# %%
plot_snippets(ts[:,0], snp[0])
# Out:
# 500
# <Axes: >

# %%
plot_snippets(ts[:,1], snp[1])
# Out:
# 500
# <Axes: >

# %%
plot_snippets(ts[:,2], snp[2])
# Out:
# 500
# <Axes: >

# %%
# INSERT YOUR CODE
labels_pred2 = np.zeros_like(ts2)
snippets_regimes2 = snp2[-1]
for regime2 in snippets_regimes2:
  labels_pred2[regime2[1] : regime2[2]] = regime2[0]

# %%
labels_pred2
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
labels2 = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 1].to_numpy()
labels2 = np.where(labels2 == 12, 0, labels2)
labels2 = np.where(labels2 == 13, 1, labels2)

# %%
labels2
# Out:
# array([ 3.,  3.,  3., ..., 17., 17., 17.])

# %%
len(labels_pred2)
# Out:
# 13429

# %%
len(labels2)
# Out:
# 2999

# %%
labels_pred3 = np.zeros_like(ts3)
snippets_regimes3 = snp3[-1]
for regime3 in snippets_regimes3:
  labels_pred3[regime3[1] : regime3[2]] = regime3[0]

# %%
labels_pred3
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
len(labels_pred3)
# Out:
# 13429

# %%
labels3 = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 1].to_numpy()
labels3 = np.where(labels3 == 12, 0, labels3)
labels3 = np.where(labels3 == 13, 1, labels3)

# %%
labels3
# Out:
# array([ 3.,  3.,  3., ..., 17., 17., 17.])

# %%
len(labels3)
# Out:
# 2999

# %% [markdown]
# Оцените точность разметки, полученной при помощи сниппетов.

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов. Сравните полученные разметки многомерного и одномерного рядов.

# %% [markdown]
# При использовании трёх осей может быть получена более высокая точность классификации.
